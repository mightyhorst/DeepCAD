# %% [markdown]
# # DeepCAD

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/mightyhorst/DeepCAD/blob/main/colab/01_pretrained_deepcad.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# 🎃 Run the pretrained model in colab

# %% [markdown]
# ## 📦 Install Conda for Colab
# When running on Colab run this cell first. It will restart the notebook so you will need to run all cells after this again.

# %%
# %pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.1.0-1/Mambaforge-23.1.0-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:17
# 🔁 Restarting kernel...

# %% [markdown]
# ## 🐙 Clone the repo
# Clone the repo from Github

# %%
# !rm -rf DeepCAD
# !git clone https://github.com/mightyhorst/DeepCAD.git
# %cd /content/DeepCAD/
# Out:
# Cloning into 'DeepCAD'...
# remote: Enumerating objects: 302, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 302 (delta 12), reused 11 (delta 7), pack-reused 285
# Receiving objects: 100% (302/302), 361.58 KiB | 21.27 MiB/s, done.
# Resolving deltas: 100% (115/115), done.

# %% [markdown]
# ## 📦 Install
# Activate conda environment called `deep-cad-env`

# %%
# !bash 01_install.sh
# !conda activate deep-cad-env

# %% [markdown]
# ## 📦 Download
# ### 👇 download data
# Download the data

# %%
# !bash 02_download_data.sh

# %% [markdown]
# ### 👇 Pretrained model
# Download the pretrained models

# %%
# !bash 03_download_pretrained_model.sh

# %% [markdown]
# ## 🏃‍♂️ Run
# ### 🏃‍♂️ Run LGAN
# Run latent GAN to generate fake latent vectors

# %%
# !export experiment_name="pretrained"
# !bash 04_run_lgan.sh

# %% [markdown]
# ### 🏃‍♂️ Run Autoencoder
# run the autoencoder to decode into final CAD sequences

# %%
# !bash 05_run_autoencoder.sh

# %% [markdown]
# ## 🕵️‍♀️ Evaluation

# %%
# !bash 06_evaluation.sh
